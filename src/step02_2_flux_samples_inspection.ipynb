# %%
import pandas as pd


control = pd.read_parquet("./results/fluxes/flux_samples_CONTROL_20_000.parquet.gzip")
pku     = pd.read_parquet("./results/fluxes/flux_samples_PKU_20_000.parquet.gzip")

# %%
control['Group'] = 'control'
pku['Group'] = 'pku'

samples = pd.concat([control, pku], axis=0).reset_index(drop=True)
import seaborn as sns

sns.swarmplot(data=samples.sample(500)[['r0399', 'Group']], x="Group", y="r0399")
# Out:
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 89.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Group', ylabel='r0399'>

# %%
sns.swarmplot(data=samples.sample(1000)[['C30CPT1', 'Group']], x="Group", y="C30CPT1")
# Out:
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 20.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 29.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Group', ylabel='C30CPT1'>
