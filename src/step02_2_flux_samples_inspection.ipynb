# %%
import pandas as pd


control = pd.read_parquet("./results/fluxes/flux_samples_CONTROL_10_000.parquet.gzip")
pku     = pd.read_parquet("./results/fluxes/flux_samples_PKU_10_000.parquet.gzip")

# %%
control['Group'] = 'control'
pku['Group'] = 'pku'

samples = pd.concat([control, pku], axis=0).reset_index(drop=True)
import seaborn as sns

sns.swarmplot(data=samples.sample(700)[['r0399', 'Group']], x="Group", y="r0399")
# Out:
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 88.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /DeepenData/.miniconda/envs/cobra/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 73.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Group', ylabel='r0399'>
