# %%
from acevedo_clss_and_fcns import * 
device = 'cpu'
if torch.cuda.is_available():
    torch.cuda.init()
    if torch.cuda.is_initialized():
        device = 'cuda:0'
print(f"{device = }")

epochs = 35


GCN_masked_flux                          =   train_and_validate(gnn_type = "GCN", mask = True, flux = True, concentration = False,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GCN_masked_concen                        =   train_and_validate(gnn_type = "GCN", mask = True, flux = False, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Concen.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GCN_masked_concen_plus_flux              =   train_and_validate(gnn_type = "GCN", mask = True, flux = True, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_Concen_plus_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")
########################################################################################################################################################
GAT_masked_flux                          =   train_and_validate(gnn_type = "GAT", mask = True, flux = True, concentration = False,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GAT_masked_concen                        =   train_and_validate(gnn_type = "GAT", mask = True, flux = False, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Concen.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GAT_masked_concen_plus_flux              =   train_and_validate(gnn_type = "GAT", mask = True, flux = True, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_Concen_plus_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")
########################################################################################################################################################
GIN_masked_flux                          =   train_and_validate(gnn_type = "GIN", mask = True, flux = True, concentration = False,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GIN_masked_concen                        =   train_and_validate(gnn_type = "GIN", mask = True, flux = False, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_only_Concen.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")

GIN_masked_concen_plus_flux              =   train_and_validate(gnn_type = "GIN", mask = True, flux = True, concentration = True,
                                                  loader_path = "./results/dataloaders/MASKED_loader_Concen_plus_Fluxes.pt" ,
                                                    EPOCHS = epochs, save = True, verbose = True, saving_folder =  "./results/trained_models/")
# Out:
# device = 'cuda:0'
#   3%|▎         | 1/35 [00:07<04:05,  7.23s/it]
# model_type = 'GCN' flux = True mask = True Epoch: 000, train_accuracy: 0.8615, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GCN/Fluxes/Model_GCN_29-12-2022_22h_30min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [04:13<00:00,  7.26s/it]
#   3%|▎         | 1/35 [00:07<04:12,  7.43s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 000, train_accuracy: 0.4994, best_validation_accuracy: 0.5018
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_35min_best_ValAcc_0.5018050541516246_epoch_0.pt
#  14%|█▍        | 5/35 [00:36<03:37,  7.24s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 004, train_accuracy: 0.7035, best_validation_accuracy: 0.6515
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_35min_best_ValAcc_0.6514856984171064_epoch_4.pt
#  17%|█▋        | 6/35 [00:43<03:29,  7.22s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 005, train_accuracy: 0.8411, best_validation_accuracy: 0.8939
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_35min_best_ValAcc_0.8939183560122188_epoch_5.pt
#  20%|██        | 7/35 [00:50<03:22,  7.23s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 006, train_accuracy: 0.9157, best_validation_accuracy: 0.9342
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_35min_best_ValAcc_0.9341849486253818_epoch_6.pt
#  26%|██▌       | 9/35 [01:05<03:08,  7.24s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 008, train_accuracy: 0.9329, best_validation_accuracy: 0.9372
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_36min_best_ValAcc_0.937239655651208_epoch_8.pt
#  29%|██▊       | 10/35 [01:12<03:01,  7.25s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 009, train_accuracy: 0.9322, best_validation_accuracy: 0.9431
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_36min_best_ValAcc_0.9430713690641489_epoch_9.pt
#  34%|███▍      | 12/35 [01:27<02:46,  7.25s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 011, train_accuracy: 0.9319, best_validation_accuracy: 0.9461
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_36min_best_ValAcc_0.946126076089975_epoch_11.pt
#  43%|████▎     | 15/35 [01:48<02:24,  7.25s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 014, train_accuracy: 0.9425, best_validation_accuracy: 0.9492
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_36min_best_ValAcc_0.9491807831158011_epoch_14.pt
#  49%|████▊     | 17/35 [02:03<02:12,  7.35s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 016, train_accuracy: 0.9490, best_validation_accuracy: 0.9503
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_37min_best_ValAcc_0.9502915856706471_epoch_16.pt
#  60%|██████    | 21/35 [02:32<01:42,  7.33s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 020, train_accuracy: 0.9528, best_validation_accuracy: 0.9564
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_37min_best_ValAcc_0.9564009997222994_epoch_20.pt
#  63%|██████▎   | 22/35 [02:40<01:34,  7.30s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 021, train_accuracy: 0.9521, best_validation_accuracy: 0.9570
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_37min_best_ValAcc_0.9569564009997223_epoch_21.pt
#  69%|██████▊   | 24/35 [02:55<01:21,  7.40s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 023, train_accuracy: 0.9537, best_validation_accuracy: 0.9595
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_37min_best_ValAcc_0.9594557067481255_epoch_23.pt
#  80%|████████  | 28/35 [03:24<00:51,  7.31s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 027, train_accuracy: 0.9545, best_validation_accuracy: 0.9622
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_38min_best_ValAcc_0.9622327131352402_epoch_27.pt
#  94%|█████████▍| 33/35 [04:01<00:14,  7.40s/it]
# model_type = 'GCN' flux = False mask = True Epoch: 032, train_accuracy: 0.9625, best_validation_accuracy: 0.9664
# saved as ./results/trained_models/Masked/GCN/Concentration/Model_GCN_29-12-2022_22h_39min_best_ValAcc_0.9663982227159122_epoch_32.pt
# 100%|██████████| 35/35 [04:15<00:00,  7.31s/it]
#   3%|▎         | 1/35 [00:07<04:05,  7.22s/it]
# model_type = 'GCN' flux = True mask = True Epoch: 000, train_accuracy: 0.7666, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GCN/Concen_plus_Fluxes/Model_GCN_29-12-2022_22h_39min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [04:18<00:00,  7.39s/it]
#   3%|▎         | 1/35 [00:09<05:12,  9.19s/it]
# model_type = 'GAT' flux = True mask = True Epoch: 000, train_accuracy: 0.8798, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GAT/Fluxes/Model_GAT_29-12-2022_22h_43min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [05:16<00:00,  9.04s/it]
#   3%|▎         | 1/35 [00:08<05:00,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 000, train_accuracy: 0.6936, best_validation_accuracy: 0.8806
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.8805887253540683_epoch_0.pt
#   6%|▌         | 2/35 [00:17<04:51,  8.83s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 001, train_accuracy: 0.8968, best_validation_accuracy: 0.8920
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.8919744515412386_epoch_1.pt
#   9%|▊         | 3/35 [00:26<04:41,  8.81s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 002, train_accuracy: 0.9268, best_validation_accuracy: 0.9297
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.9297417384059984_epoch_2.pt
#  11%|█▏        | 4/35 [00:35<04:33,  8.82s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 003, train_accuracy: 0.9393, best_validation_accuracy: 0.9389
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.9389058594834768_epoch_3.pt
#  14%|█▍        | 5/35 [00:44<04:25,  8.87s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 004, train_accuracy: 0.9473, best_validation_accuracy: 0.9483
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.9483476811996667_epoch_4.pt
#  17%|█▋        | 6/35 [00:53<04:17,  8.88s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 005, train_accuracy: 0.9505, best_validation_accuracy: 0.9500
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.9500138850319356_epoch_5.pt
#  20%|██        | 7/35 [01:02<04:08,  8.88s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 006, train_accuracy: 0.9550, best_validation_accuracy: 0.9545
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_49min_best_ValAcc_0.954457095251319_epoch_6.pt
#  23%|██▎       | 8/35 [01:10<03:59,  8.86s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 007, train_accuracy: 0.9598, best_validation_accuracy: 0.9578
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_50min_best_ValAcc_0.9577895029158567_epoch_7.pt
#  26%|██▌       | 9/35 [01:19<03:50,  8.85s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 008, train_accuracy: 0.9627, best_validation_accuracy: 0.9631
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_50min_best_ValAcc_0.9630658150513746_epoch_8.pt
#  29%|██▊       | 10/35 [01:28<03:41,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 009, train_accuracy: 0.9651, best_validation_accuracy: 0.9647
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_50min_best_ValAcc_0.9647320188836435_epoch_9.pt
#  31%|███▏      | 11/35 [01:37<03:31,  8.82s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 010, train_accuracy: 0.9685, best_validation_accuracy: 0.9678
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_50min_best_ValAcc_0.9677867259094696_epoch_10.pt
#  37%|███▋      | 13/35 [01:55<03:14,  8.85s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 012, train_accuracy: 0.9722, best_validation_accuracy: 0.9697
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_50min_best_ValAcc_0.9697306303804498_epoch_12.pt
#  40%|████      | 14/35 [02:03<03:05,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 013, train_accuracy: 0.9728, best_validation_accuracy: 0.9708
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_51min_best_ValAcc_0.9708414329352958_epoch_13.pt
#  43%|████▎     | 15/35 [02:12<02:56,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 014, train_accuracy: 0.9750, best_validation_accuracy: 0.9750
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_51min_best_ValAcc_0.9750069425159678_epoch_14.pt
#  51%|█████▏    | 18/35 [02:39<02:30,  8.83s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 017, train_accuracy: 0.9774, best_validation_accuracy: 0.9795
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_51min_best_ValAcc_0.9794501527353513_epoch_17.pt
#  66%|██████▌   | 23/35 [03:23<01:45,  8.83s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 022, train_accuracy: 0.9789, best_validation_accuracy: 0.9817
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_52min_best_ValAcc_0.981671757845043_epoch_22.pt
#  74%|███████▍  | 26/35 [03:49<01:19,  8.83s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 025, train_accuracy: 0.9811, best_validation_accuracy: 0.9831
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_52min_best_ValAcc_0.9830602610386003_epoch_25.pt
#  83%|████████▎ | 29/35 [04:16<00:53,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 028, train_accuracy: 0.9827, best_validation_accuracy: 0.9833
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_53min_best_ValAcc_0.9833379616773119_epoch_28.pt
#  91%|█████████▏| 32/35 [04:43<00:26,  8.87s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 031, train_accuracy: 0.9840, best_validation_accuracy: 0.9842
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_53min_best_ValAcc_0.9841710635934463_epoch_31.pt
#  97%|█████████▋| 34/35 [05:00<00:08,  8.84s/it]
# model_type = 'GAT' flux = False mask = True Epoch: 033, train_accuracy: 0.9851, best_validation_accuracy: 0.9847
# saved as ./results/trained_models/Masked/GAT/Concentration/Model_GAT_29-12-2022_22h_53min_best_ValAcc_0.9847264648708692_epoch_33.pt
# 100%|██████████| 35/35 [05:09<00:00,  8.84s/it]
#   3%|▎         | 1/35 [00:08<04:59,  8.81s/it]
# model_type = 'GAT' flux = True mask = True Epoch: 000, train_accuracy: 0.8529, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GAT/Concen_plus_Fluxes/Model_GAT_29-12-2022_22h_54min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [05:08<00:00,  8.82s/it]
#   3%|▎         | 1/35 [00:06<03:30,  6.21s/it]
# model_type = 'GIN' flux = True mask = True Epoch: 000, train_accuracy: 0.6305, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GIN/Fluxes/Model_GIN_29-12-2022_22h_59min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [03:39<00:00,  6.28s/it]
#   3%|▎         | 1/35 [00:06<03:31,  6.23s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 000, train_accuracy: 0.6635, best_validation_accuracy: 0.6121
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.6120522077200777_epoch_0.pt
#   6%|▌         | 2/35 [00:12<03:24,  6.21s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 001, train_accuracy: 0.9022, best_validation_accuracy: 0.9339
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9339072479866704_epoch_1.pt
#   9%|▊         | 3/35 [00:18<03:18,  6.19s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 002, train_accuracy: 0.9413, best_validation_accuracy: 0.9458
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9458483754512635_epoch_2.pt
#  11%|█▏        | 4/35 [00:24<03:11,  6.18s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 003, train_accuracy: 0.9545, best_validation_accuracy: 0.9561
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9561232990835878_epoch_3.pt
#  14%|█▍        | 5/35 [00:30<03:04,  6.16s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 004, train_accuracy: 0.9577, best_validation_accuracy: 0.9625
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9625104137739516_epoch_4.pt
#  20%|██        | 7/35 [00:43<02:53,  6.18s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 006, train_accuracy: 0.9665, best_validation_accuracy: 0.9670
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9669536239933352_epoch_6.pt
#  26%|██▌       | 9/35 [00:55<02:40,  6.17s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 008, train_accuracy: 0.9675, best_validation_accuracy: 0.9706
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_03min_best_ValAcc_0.9705637322965843_epoch_8.pt
#  31%|███▏      | 11/35 [01:08<02:29,  6.22s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 010, train_accuracy: 0.9722, best_validation_accuracy: 0.9731
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_04min_best_ValAcc_0.9730630380449875_epoch_10.pt
#  37%|███▋      | 13/35 [01:20<02:17,  6.24s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 012, train_accuracy: 0.9741, best_validation_accuracy: 0.9742
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_04min_best_ValAcc_0.9741738405998334_epoch_12.pt
#  49%|████▊     | 17/35 [01:45<01:51,  6.18s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 016, train_accuracy: 0.9743, best_validation_accuracy: 0.9781
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_04min_best_ValAcc_0.978061649541794_epoch_16.pt
#  57%|█████▋    | 20/35 [02:03<01:32,  6.18s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 019, train_accuracy: 0.9717, best_validation_accuracy: 0.9800
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_05min_best_ValAcc_0.9800055540127742_epoch_19.pt
#  60%|██████    | 21/35 [02:10<01:26,  6.19s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 020, train_accuracy: 0.9773, best_validation_accuracy: 0.9817
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_05min_best_ValAcc_0.981671757845043_epoch_20.pt
#  69%|██████▊   | 24/35 [02:29<01:10,  6.44s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 023, train_accuracy: 0.9746, best_validation_accuracy: 0.9831
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_05min_best_ValAcc_0.9830602610386003_epoch_23.pt
#  71%|███████▏  | 25/35 [02:36<01:04,  6.43s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 024, train_accuracy: 0.9784, best_validation_accuracy: 0.9833
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_05min_best_ValAcc_0.9833379616773119_epoch_24.pt
# 100%|██████████| 35/35 [03:38<00:00,  6.23s/it]
# model_type = 'GIN' flux = False mask = True Epoch: 034, train_accuracy: 0.9788, best_validation_accuracy: 0.9853
# saved as ./results/trained_models/Masked/GIN/Concentration/Model_GIN_29-12-2022_23h_06min_best_ValAcc_0.9852818661482922_epoch_34.pt
#   3%|▎         | 1/35 [00:06<03:32,  6.26s/it]
# model_type = 'GIN' flux = True mask = True Epoch: 000, train_accuracy: 0.8808, best_validation_accuracy: 0.9953
# saved as ./results/trained_models/Masked/GIN/Concen_plus_Fluxes/Model_GIN_29-12-2022_23h_06min_best_ValAcc_0.995279089141905_epoch_0.pt
# 100%|██████████| 35/35 [03:33<00:00,  6.11s/it]

# %%
test_loader_MASKED_loader_only_Fluxes        = torch.load("./results/dataloaders/MASKED_loader_only_Fluxes.pt").get_test_loader()
test_loader_MASKED_loader_only_Concen        = torch.load("./results/dataloaders/MASKED_loader_only_Concen.pt").get_test_loader()
test_loader_MASKED_loader_Concen_plus_Fluxes = torch.load("./results/dataloaders/MASKED_loader_Concen_plus_Fluxes.pt").get_test_loader()

# %%
##GCN
GCN_base_fpr_F,  GCN_mean_tprs_F, GCN_tprs_lower_F,   GCN_tprs_upper_F,  GCN_mean_auc_F,  GCN_std_auc_F  = get_ROC_parameters(GCN_masked_flux[0], test_loader_MASKED_loader_only_Fluxes)
GCN_base_fpr_C,  GCN_mean_tprs_C, GCN_tprs_lower_C,   GCN_tprs_upper_C,  GCN_mean_auc_C,  GCN_std_auc_C  = get_ROC_parameters(GCN_masked_concen[0], test_loader_MASKED_loader_only_Concen)
GCN_base_fpr_CF, GCN_mean_tprs_CF, GCN_tprs_lower_CF, GCN_tprs_upper_CF, GCN_mean_auc_CF, GCN_std_auc_CF = get_ROC_parameters(GCN_masked_concen_plus_flux[0], test_loader_MASKED_loader_Concen_plus_Fluxes)
#GAT
GAT_base_fpr_F,  GAT_mean_tprs_F, GAT_tprs_lower_F,   GAT_tprs_upper_F,  GAT_mean_auc_F,  GAT_std_auc_F  = get_ROC_parameters(GAT_masked_flux[0], test_loader_MASKED_loader_only_Fluxes)
GAT_base_fpr_C,  GAT_mean_tprs_C, GAT_tprs_lower_C,   GAT_tprs_upper_C,  GAT_mean_auc_C,  GAT_std_auc_C  = get_ROC_parameters(GAT_masked_concen[0], test_loader_MASKED_loader_only_Concen)
GAT_base_fpr_CF, GAT_mean_tprs_CF, GAT_tprs_lower_CF, GAT_tprs_upper_CF, GAT_mean_auc_CF, GAT_std_auc_CF = get_ROC_parameters(GAT_masked_concen_plus_flux[0], test_loader_MASKED_loader_Concen_plus_Fluxes)
#GIN
GIN_base_fpr_F,  GIN_mean_tprs_F, GIN_tprs_lower_F,   GIN_tprs_upper_F,  GIN_mean_auc_F,  GIN_std_auc_F  = get_ROC_parameters(GIN_masked_flux[0], test_loader_MASKED_loader_only_Fluxes)
GIN_base_fpr_C,  GIN_mean_tprs_C, GIN_tprs_lower_C,   GIN_tprs_upper_C,  GIN_mean_auc_C,  GIN_std_auc_C  = get_ROC_parameters(GIN_masked_concen[0], test_loader_MASKED_loader_only_Concen)
GIN_base_fpr_CF, GIN_mean_tprs_CF, GIN_tprs_lower_CF, GIN_tprs_upper_CF, GIN_mean_auc_CF, GIN_std_auc_CF = get_ROC_parameters(GIN_masked_concen_plus_flux[0], test_loader_MASKED_loader_Concen_plus_Fluxes)

# %%
fig = plt.figure(figsize=(16,12))
ax0 = plt.subplot2grid((4, 3), (0, 0), colspan=1)
ax1 = plt.subplot2grid((4, 3), (1, 0), colspan=1)
ax2 = plt.subplot2grid((4, 3), (0, 1), colspan=1)

ax3 = plt.subplot2grid((4, 3), (1, 1), colspan=1)
ax4 = plt.subplot2grid((4, 3), (0, 2), colspan=1)
ax5 = plt.subplot2grid((4, 3), (1, 2), colspan=1)


ax6 = plt.subplot2grid((4, 3), (2, 0), colspan=1)
ax7 = plt.subplot2grid((4, 3), (3, 0), colspan=1)
ax8 = plt.subplot2grid((4, 3), (2, 1), colspan=1)


ax9 = plt.subplot2grid((4, 3), (3, 1), colspan=1)
ax10 = plt.subplot2grid((4, 3), (2, 2), colspan=1)
ax11 = plt.subplot2grid((4, 3), (3, 2), colspan=1)

#ax12 = plt.subplot2grid((4, 3), (2, 2), colspan=1)

plt.subplots_adjust(left=0.1, bottom=0.1, right=.7, top=1.05, wspace=0.3, hspace=0.3)    

# FLUX
put_Learning_curve(GCN_masked_flux[1], GCN_masked_flux[2], ax0, 'GCN Flux')
put_Learning_curve(GAT_masked_flux[1], GAT_masked_flux[2], ax2, 'GAT Flux')
put_Learning_curve(GIN_masked_flux[1], GIN_masked_flux[2], ax4, 'GIN Flux')

put_ROC_in_subplot(GCN_base_fpr_F,  GCN_mean_tprs_F, GCN_tprs_lower_F,   GCN_tprs_upper_F,  GCN_mean_auc_F,  GCN_std_auc_F,
                   ax1, xlabel = 'False Positive Rate', letter = 'GCN Flux')
put_ROC_in_subplot(GAT_base_fpr_F,  GAT_mean_tprs_F, GAT_tprs_lower_F,   GAT_tprs_upper_F,  GAT_mean_auc_F,  GAT_std_auc_F ,
                   ax3, xlabel = 'False Positive Rate', letter = 'GAT Flux')
put_ROC_in_subplot(GIN_base_fpr_F,  GIN_mean_tprs_F, GIN_tprs_lower_F,   GIN_tprs_upper_F,  GIN_mean_auc_F,  GIN_std_auc_F ,
                   ax5, xlabel = 'False Positive Rate', letter = 'GIN Flux')

#Concentration
put_Learning_curve(GCN_masked_concen[1], GCN_masked_concen[2], ax6, 'GCN Concentration')
put_Learning_curve(GAT_masked_concen[1], GAT_masked_concen[2], ax8, 'GAT Concentration')
put_Learning_curve(GIN_masked_concen[1], GIN_masked_concen[2], ax10, 'GIN Concentration')

put_ROC_in_subplot(GCN_base_fpr_C,  GCN_mean_tprs_C, GCN_tprs_lower_C,   GCN_tprs_upper_C,  GCN_mean_auc_C,  GCN_std_auc_C,
                   ax7, xlabel = 'False Positive Rate', letter = 'GCN Concentration')
put_ROC_in_subplot(GAT_base_fpr_C,  GAT_mean_tprs_C, GAT_tprs_lower_C,   GAT_tprs_upper_C,  GAT_mean_auc_C,  GAT_std_auc_C ,
                   ax9, xlabel = 'False Positive Rate', letter = 'GAT Concentration')
put_ROC_in_subplot(GIN_base_fpr_C,  GIN_mean_tprs_C, GIN_tprs_lower_C,   GIN_tprs_upper_C,  GIN_mean_auc_C,  GIN_std_auc_C ,
                   ax11, xlabel = 'False Positive Rate', letter = 'GIN Concentration')

# %%
learning_results = {
'GCN_masked_flux': GCN_masked_flux,
'GCN_masked_concen' : GCN_masked_concen,
'GCN_masked_concen_plus_flux': GCN_masked_concen_plus_flux, 
#
#
'GAT_masked_flux' : GAT_masked_flux,
'GAT_masked_concen' : GAT_masked_concen,
'GAT_masked_concen_plus_flux': GAT_masked_concen_plus_flux, 
#
'GIN_masked_flux' : GIN_masked_flux,
'GIN_masked_concen' : GIN_masked_concen,
'GIN_masked_concen_plus_flux' : GIN_masked_concen_plus_flux,

}

# %%
import pickle

#a = learning_results

with open('./results/training_and_validation_data/learning_results.pickle', 'wb') as handle:
    pickle.dump(learning_results, handle, protocol=pickle.HIGHEST_PROTOCOL)
